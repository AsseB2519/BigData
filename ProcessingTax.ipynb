# %% [markdown]
# <center>
#
# # $\textbf{Tax}$
#
# <center>

# %% [markdown]
# ### $\textbf{Code}$

# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame with semicolon as the delimiter
df = pd.read_csv('Files/Tax.csv', sep=';')

# %%
# Select the columns you're interested in
selected_columns = ['country', 'year', 'tax_complexity_index', 'population']

# %%
# Create a new DataFrame with only the selected columns
tax = df[selected_columns].copy()

# %%
# Rename Column Value to tax
tax.rename(columns={'tax_complexity_index': 'tax'}, inplace=True)

# %%
# Save the selected data to a new CSV file
tax.to_csv("FinalFiles/Tax.csv", index=False)
